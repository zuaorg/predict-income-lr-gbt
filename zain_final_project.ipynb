# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
.appName("FinalProject").config("spark.driver.bindAddress", "127.0.0.1").getOrCreate()

adult_df = spark.read.csv("adult/adult.data", inferSchema = True)
adult_df2 = spark.read.csv("adult/adult.test", inferSchema = True)


adult_df2.show()
# Out:
# 24/12/07 00:39:07 WARN Utils: Your hostname, Zains-Mac.local resolves to a loopback address: 127.0.0.1, but we couldn't find any external IP address!
# 24/12/07 00:39:07 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/07 00:39:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +---+-----------------+--------+-------------+----+-------------------+------------------+--------------+-------------------+-------+------+----+----+--------------+-------+
# |_c0|              _c1|     _c2|          _c3| _c4|                _c5|               _c6|           _c7|                _c8|    _c9|  _c10|_c11|_c12|          _c13|   _c14|
# +---+-----------------+--------+-------------+----+-------------------+------------------+--------------+-------------------+-------+------+----+----+--------------+-------+
# | 25|          Private|226802.0|         11th| 7.0|      Never-married| Machine-op-inspct|     Own-child|              Black|   Male|   0.0| 0.0|40.0| United-States| <=50K.|
# | 38|          Private| 89814.0|      HS-grad| 9.0| Married-civ-spouse|   Farming-fishing|       Husband|              White|   Male|   0.0| 0.0|50.0| United-States| <=50K.|
# | 28|        Local-gov|336951.0|   Assoc-acdm|12.0| Married-civ-spouse|   Protective-serv|       Husband|              White|   Male|   0.0| 0.0|40.0| United-States|  >50K.|
# | 44|          Private|160323.0| Some-college|10.0| Married-civ-spouse| Machine-op-inspct|       Husband|              Black|   Male|7688.0| 0.0|40.0| United-States|  >50K.|
# | 18|                ?|103497.0| Some-college|10.0|      Never-married|                 ?|     Own-child|              White| Female|   0.0| 0.0|30.0| United-States| <=50K.|
# | 34|          Private|198693.0|         10th| 6.0|      Never-married|     Other-service| Not-in-family|              White|   Male|   0.0| 0.0|30.0| United-States| <=50K.|
# | 29|                ?|227026.0|      HS-grad| 9.0|      Never-married|                 ?|     Unmarried|              Black|   Male|   0.0| 0.0|40.0| United-States| <=50K.|
# | 63| Self-emp-not-inc|104626.0|  Prof-school|15.0| Married-civ-spouse|    Prof-specialty|       Husband|              White|   Male|3103.0| 0.0|32.0| United-States|  >50K.|
# | 24|          Private|369667.0| Some-college|10.0|      Never-married|     Other-service|     Unmarried|              White| Female|   0.0| 0.0|40.0| United-States| <=50K.|
# | 55|          Private|104996.0|      7th-8th| 4.0| Married-civ-spouse|      Craft-repair|       Husband|              White|   Male|   0.0| 0.0|10.0| United-States| <=50K.|
# | 65|          Private|184454.0|      HS-grad| 9.0| Married-civ-spouse| Machine-op-inspct|       Husband|              White|   Male|6418.0| 0.0|40.0| United-States|  >50K.|
# | 36|      Federal-gov|212465.0|    Bachelors|13.0| Married-civ-spouse|      Adm-clerical|       Husband|              White|   Male|   0.0| 0.0|40.0| United-States| <=50K.|
# | 26|          Private| 82091.0|      HS-grad| 9.0|      Never-married|      Adm-clerical| Not-in-family|              White| Female|   0.0| 0.0|39.0| United-States| <=50K.|
# | 58|                ?|299831.0|      HS-grad| 9.0| Married-civ-spouse|                 ?|       Husband|              White|   Male|   0.0| 0.0|35.0| United-States| <=50K.|
# | 48|          Private|279724.0|      HS-grad| 9.0| Married-civ-spouse| Machine-op-inspct|       Husband|              White|   Male|3103.0| 0.0|48.0| United-States|  >50K.|
# | 43|          Private|346189.0|      Masters|14.0| Married-civ-spouse|   Exec-managerial|       Husband|              White|   Male|   0.0| 0.0|50.0| United-States|  >50K.|
# | 20|        State-gov|444554.0| Some-college|10.0|      Never-married|     Other-service|     Own-child|              White|   Male|   0.0| 0.0|25.0| United-States| <=50K.|
# | 43|          Private|128354.0|      HS-grad| 9.0| Married-civ-spouse|      Adm-clerical|          Wife|              White| Female|   0.0| 0.0|30.0| United-States| <=50K.|
# | 37|          Private| 60548.0|      HS-grad| 9.0|            Widowed| Machine-op-inspct|     Unmarried|              White| Female|   0.0| 0.0|20.0| United-States| <=50K.|
# | 40|          Private| 85019.0|    Doctorate|16.0| Married-civ-spouse|    Prof-specialty|       Husband| Asian-Pac-Islander|   Male|   0.0| 0.0|45.0|             ?|  >50K.|
# +---+-----------------+--------+-------------+----+-------------------+------------------+--------------+-------------------+-------+------+----+----+--------------+-------+
# only showing top 20 rows

# %%
# column headers
columns = [
    "age", "workclass", "fnlwgt", "education", "education-num",
    "marital-status", "occupation", "relationship", "race", "sex",
    "capital-gain", "capital-loss", "hours-per-week", "native-country",
    "income"
]

# Adding column headers
adult_df = adult_df.toDF(*columns)
adult_df2 = adult_df2.toDF(*columns)

# Combining old data to create a unified set
combined_df = adult_df.union(adult_df2)

adult_df.show()
# Out:
# +---+-----------------+--------+-------------+-------------+--------------------+------------------+--------------+-------------------+-------+------------+------------+--------------+--------------+------+
# |age|        workclass|  fnlwgt|    education|education-num|      marital-status|        occupation|  relationship|               race|    sex|capital-gain|capital-loss|hours-per-week|native-country|income|
# +---+-----------------+--------+-------------+-------------+--------------------+------------------+--------------+-------------------+-------+------------+------------+--------------+--------------+------+
# | 39|        State-gov| 77516.0|    Bachelors|         13.0|       Never-married|      Adm-clerical| Not-in-family|              White|   Male|      2174.0|         0.0|          40.0| United-States| <=50K|
# | 50| Self-emp-not-inc| 83311.0|    Bachelors|         13.0|  Married-civ-spouse|   Exec-managerial|       Husband|              White|   Male|         0.0|         0.0|          13.0| United-States| <=50K|
# | 38|          Private|215646.0|      HS-grad|          9.0|            Divorced| Handlers-cleaners| Not-in-family|              White|   Male|         0.0|         0.0|          40.0| United-States| <=50K|
# | 53|          Private|234721.0|         11th|          7.0|  Married-civ-spouse| Handlers-cleaners|       Husband|              Black|   Male|         0.0|         0.0|          40.0| United-States| <=50K|
# | 28|          Private|338409.0|    Bachelors|         13.0|  Married-civ-spouse|    Prof-specialty|          Wife|              Black| Female|         0.0|         0.0|          40.0|          Cuba| <=50K|
# | 37|          Private|284582.0|      Masters|         14.0|  Married-civ-spouse|   Exec-managerial|          Wife|              White| Female|         0.0|         0.0|          40.0| United-States| <=50K|
# | 49|          Private|160187.0|          9th|          5.0| Married-spouse-a...|     Other-service| Not-in-family|              Black| Female|         0.0|         0.0|          16.0|       Jamaica| <=50K|
# | 52| Self-emp-not-inc|209642.0|      HS-grad|          9.0|  Married-civ-spouse|   Exec-managerial|       Husband|              White|   Male|         0.0|         0.0|          45.0| United-States|  >50K|
# | 31|          Private| 45781.0|      Masters|         14.0|       Never-married|    Prof-specialty| Not-in-family|              White| Female|     14084.0|         0.0|          50.0| United-States|  >50K|
# | 42|          Private|159449.0|    Bachelors|         13.0|  Married-civ-spouse|   Exec-managerial|       Husband|              White|   Male|      5178.0|         0.0|          40.0| United-States|  >50K|
# | 37|          Private|280464.0| Some-college|         10.0|  Married-civ-spouse|   Exec-managerial|       Husband|              Black|   Male|         0.0|         0.0|          80.0| United-States|  >50K|
# | 30|        State-gov|141297.0|    Bachelors|         13.0|  Married-civ-spouse|    Prof-specialty|       Husband| Asian-Pac-Islander|   Male|         0.0|         0.0|          40.0|         India|  >50K|
# | 23|          Private|122272.0|    Bachelors|         13.0|       Never-married|      Adm-clerical|     Own-child|              White| Female|         0.0|         0.0|          30.0| United-States| <=50K|
# | 32|          Private|205019.0|   Assoc-acdm|         12.0|       Never-married|             Sales| Not-in-family|              Black|   Male|         0.0|         0.0|          50.0| United-States| <=50K|
# | 40|          Private|121772.0|    Assoc-voc|         11.0|  Married-civ-spouse|      Craft-repair|       Husband| Asian-Pac-Islander|   Male|         0.0|         0.0|          40.0|             ?|  >50K|
# | 34|          Private|245487.0|      7th-8th|          4.0|  Married-civ-spouse|  Transport-moving|       Husband| Amer-Indian-Eskimo|   Male|         0.0|         0.0|          45.0|        Mexico| <=50K|
# | 25| Self-emp-not-inc|176756.0|      HS-grad|          9.0|       Never-married|   Farming-fishing|     Own-child|              White|   Male|         0.0|         0.0|          35.0| United-States| <=50K|
# | 32|          Private|186824.0|      HS-grad|          9.0|       Never-married| Machine-op-inspct|     Unmarried|              White|   Male|         0.0|         0.0|          40.0| United-States| <=50K|
# | 38|          Private| 28887.0|         11th|          7.0|  Married-civ-spouse|             Sales|       Husband|              White|   Male|         0.0|         0.0|          50.0| United-States| <=50K|
# | 43| Self-emp-not-inc|292175.0|      Masters|         14.0|            Divorced|   Exec-managerial|     Unmarried|              White| Female|         0.0|         0.0|          45.0| United-States|  >50K|
# +---+-----------------+--------+-------------+-------------+--------------------+------------------+--------------+-------------------+-------+------------+------------+--------------+--------------+------+
# only showing top 20 rows

# %%
count = combined_df.count()
print(f"Total number of rows: {count}")
# Out:
# Total number of rows: 48842

# %%
from pyspark.sql.functions import col, regexp_replace

# Dropping rows with missing values
df_cleaned = combined_df.dropna()

# Show the distinct values in label income column to clean data
distinct_values = df_cleaned.select("income").distinct()
print("Income column before cleaning:")
distinct_values.show(truncate=False)

# Remove trailing spaces or periods from the 'income' column
df_cleaned = df_cleaned.withColumn("income", regexp_replace(col("income"), "\\.", ""))

# Show the distinct values after cleaning
distinct_values = df_cleaned.select("income").distinct()
print("Income column after cleaning:")
distinct_values.show(truncate=False)
# Out:
# Income column before cleaning:
# +-------+
# |income |
# +-------+
# | >50K  |
# | <=50K |
# | >50K. |
# | <=50K.|
# +-------+
#
# Income column after cleaning:
# +------+
# |income|
# +------+
# | >50K |
# | <=50K|
# +------+

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml import Pipeline

# Distilling the features and labels
feature_columns = [
    "age", "workclass", "fnlwgt", "education", "education-num", 
    "marital-status", "occupation", "relationship", "race", "sex", 
    "capital-gain", "capital-loss", "hours-per-week", "native-country"
]
label_column = "income"

# One-hot encoding categorical features (first indexing then encoding)
categorical_columns = [
    "workclass", "education", "marital-status", "occupation", 
    "relationship", "race", "sex", "native-country"
]
numerical_columns = ["age", "fnlwgt", "education-num", "capital-gain", "capital-loss", "hours-per-week"]

indexer_income = StringIndexer(inputCol=label_column, outputCol="label")
# StringIndexer and OneHotEncoder stages for categorical columns
indexers = [StringIndexer(inputCol=col, outputCol=col + "_index") for col in categorical_columns]
encoders = [OneHotEncoder(inputCols=[col + "_index"], outputCols=[col + "_onehot"]) for col in categorical_columns]

# all features combined into a single vector column
assembler = VectorAssembler(
    inputCols=[col + "_onehot" for col in categorical_columns] + numerical_columns,
    outputCol="features"
)

# pipeline with stages indexer, encoder, assembler
pipeline = Pipeline(stages=[indexer_income] + indexers + encoders + [assembler])

# Fit and transform
model = pipeline.fit(df_cleaned)
processed_data = model.transform(df_cleaned)

# Selecting features and labels
final_data = processed_data.select("features", "label")

final_data.show(5)
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |(100,[4,10,24,32,...|  0.0|
# |(100,[1,10,23,31,...|  0.0|
# |(100,[0,8,25,38,4...|  0.0|
# |(100,[0,13,23,38,...|  0.0|
# |(100,[0,10,23,29,...|  0.0|
# +--------------------+-----+
# only showing top 5 rows
# 24/12/07 00:39:13 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
# Splitting the dataset 80-20 into training and testing sets
train_data, test_data = final_data.randomSplit([0.8, 0.2], seed=100)

# Training and testing dataset count
print("Number of training samples:", train_data.count())
print("Number of testing samples:", test_data.count())
# Out:
# Number of training samples: 39119
# Number of testing samples: 9723

# %%
from pyspark.ml.classification import LogisticRegression as MLlibLR, GBTClassifier as MLlibGBT

# Logistic Regression Model
lr = MLlibLR(featuresCol='features', labelCol='label')
print("Training logistic regression model...")
lr_model = lr.fit(train_data)
print("Model trained successfully!")

# Gradient-Boosted Tree Model (GBT)
gbt = MLlibGBT(featuresCol='features', labelCol='label')
print("Training gradient-boosted tree model...")
gbt_model = gbt.fit(train_data)
print("Model trained successfully!")
# Out:
# Training logistic regression model...
# 24/12/07 00:39:15 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 24/12/07 00:39:15 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# Model trained successfully!
# Training gradient-boosted tree model...
# Model trained successfully!

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# Using BinaryClassificationEvaluator to evaluate models
evaluator = BinaryClassificationEvaluator(labelCol='label', metricName="areaUnderROC")

# Logistic Regression Grid Search and grid parameter
lr_param_grid = ParamGridBuilder() \
    .addGrid(lr.regParam, [0.01, 0.1, 0.5]) \
    .addGrid(lr.maxIter, [10, 50, 100]) \
    .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0]) \
    .build()

# Cross-Validator for Logistic Regression
lr_cross_validator = CrossValidator(
    estimator=lr,
    estimatorParamMaps=lr_param_grid,
    evaluator=evaluator,
    numFolds=5  # 5-fold cross-validation
)

# Gradient-Boosted Tree Grid Search and grid parameter
gbt_param_grid = ParamGridBuilder() \
    .addGrid(gbt.maxDepth, [5, 10]) \
    .addGrid(gbt.maxIter, [10, 20]) \
    .addGrid(gbt.stepSize, [0.1, 0.2]) \
    .build()

# Cross-Validator for GBT
gbt_cross_validator = CrossValidator(
    estimator=gbt,
    estimatorParamMaps=gbt_param_grid,
    evaluator=evaluator,
    numFolds=5,  # 5-fold cross-validation
    parallelism=4
)

# Logistic Regression Model with Cross-Validation
print("Training logistic regression model with cross-validation...")
lr_cv_model = lr_cross_validator.fit(train_data)
print("Logistic Regression model trained successfully!")

# best logistic regression model
best_lr_model = lr_cv_model.bestModel
print(f"Best Logistic Regression Model: {best_lr_model}")

# Gradient-Boosted Tree Model with Cross-Validation
print("Training gradient-boosted tree model with cross-validation...")
gbt_cv_model = gbt_cross_validator.fit(train_data)
print("Gradient-Boosted Tree model trained successfully!")

# best GBT model
best_gbt_model = gbt_cv_model.bestModel
print(f"Best Gradient-Boosted Tree Model: {best_gbt_model}")
# Out:
# Training logistic regression model with cross-validation...
# 24/12/07 00:39:45 WARN BlockManager: Asked to remove block broadcast_3268, which does not exist
# Logistic Regression model trained successfully!
# Best Logistic Regression Model: LogisticRegressionModel: uid=LogisticRegression_db6a78cdf70e, numClasses=2, numFeatures=100
# Training gradient-boosted tree model with cross-validation...
# 24/12/07 00:40:31 WARN BlockManager: Block rdd_11939_1 already exists on this machine; not re-adding it
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1007.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1030.6 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1029.6 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1030.1 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1030.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1031.8 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1033.9 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1037.4 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1042.8 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1052.8 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1069.4 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1095.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1096.4 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1096.9 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1018.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1097.5 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1052.0 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1098.6 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1101.0 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1052.0 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1104.9 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1052.6 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1110.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1053.1 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1120.7 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1054.2 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1138.1 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1056.3 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1165.0 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1059.8 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1065.2 KiB
# 24/12/07 00:40:41 WARN DAGScheduler: Broadcasting large task binary with size 1165.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1074.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1165.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1089.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1166.2 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1167.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1169.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.2 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1173.0 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1117.7 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1177.9 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1118.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1186.8 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1119.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1202.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1121.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1228.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1125.0 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1130.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1229.2 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1141.0 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1229.7 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1158.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1230.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1184.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1231.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1233.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1184.3 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1236.9 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1184.8 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1242.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1185.4 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1253.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1186.5 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1272.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1188.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1301.7 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1192.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1197.9 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1303.1 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1208.2 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1303.6 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1225.9 KiB
# 24/12/07 00:40:42 WARN DAGScheduler: Broadcasting large task binary with size 1304.2 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1255.0 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1305.3 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1307.6 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1255.4 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1311.4 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1256.0 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1318.1 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1256.5 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1330.7 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1257.6 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1352.4 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1259.7 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1385.8 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1263.3 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1268.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1384.8 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1279.6 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1385.3 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1296.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1385.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1323.6 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1387.0 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1389.0 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1321.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1392.5 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1322.4 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1397.7 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1322.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1407.6 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1324.1 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1425.2 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1326.5 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1454.3 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1330.5 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1336.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1455.8 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1347.7 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1456.3 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1365.9 KiB
# 24/12/07 00:40:43 WARN DAGScheduler: Broadcasting large task binary with size 1456.9 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1393.9 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1458.0 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1460.0 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1393.4 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1463.6 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1393.9 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1469.3 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1394.4 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1479.7 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1395.6 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1498.8 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1397.7 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1529.5 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1401.3 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1406.9 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1531.7 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1417.4 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1532.2 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1435.6 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1532.8 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1464.4 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1533.9 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1465.7 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 1536.1 KiB
# 24/12/07 00:40:44 WARN DAGScheduler: Broadcasting large task binary with size 
KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1100.4 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1034.7 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1101.5 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1035.2 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1103.9 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1035.8 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1108.3 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1036.9 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1115.6 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1039.3 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1129.5 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1043.4 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1151.9 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1049.8 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1186.3 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1061.5 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1080.5 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1183.8 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1109.8 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1184.3 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1184.9 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1108.5 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1186.0 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1109.0 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1188.1 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1109.6 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1191.9 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1110.7 KiB
# 24/12/07 00:41:43 WARN DAGScheduler: Broadcasting large task binary with size 1197.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1112.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1209.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1116.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1230.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1122.1 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1264.8 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1132.5 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1150.1 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1266.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1179.6 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1267.2 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1267.8 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1180.8 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1268.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1181.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1271.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1181.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1274.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1183.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1280.4 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1185.1 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1291.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1188.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1310.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1194.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1339.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1204.6 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1222.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1337.5 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1249.5 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1338.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1338.6 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1250.8 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1339.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1251.3 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1342.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1251.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1346.2 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1253.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1352.7 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1255.1 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1365.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1258.9 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1386.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1264.0 KiB
# 24/12/07 00:41:44 WARN DAGScheduler: Broadcasting large task binary with size 1415.5 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1274.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1413.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1291.0 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1413.7 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1319.4 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1414.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1415.4 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1321.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1417.5 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1321.7 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1421.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1322.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1426.9 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1323.4 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1438.0 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1325.8 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1456.9 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1330.1 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1485.6 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1337.4 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1350.8 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1484.0 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1372.9 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1484.5 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1404.6 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1485.1 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1486.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1402.1 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1488.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1402.7 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1492.1 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1403.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1497.9 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1404.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1509.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1406.4 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1528.2 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1410.3 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1559.0 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1416.0 KiB
# 24/12/07 00:41:45 WARN DAGScheduler: Broadcasting large task binary with size 1558.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1426.9 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1444.6 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1558.6 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1471.5 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1559.1 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1560.3 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1471.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1562.6 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1471.5 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1566.8 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1472.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1573.7 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1473.2 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1585.9 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1475.3 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1606.1 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1479.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1637.4 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1484.7 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1496.5 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1636.4 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1515.8 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1636.9 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1545.8 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1637.5 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1638.6 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1544.9 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1640.7 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1545.4 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1644.5 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1546.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1650.1 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1547.1 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1661.3 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1549.4 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1679.8 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1553.8 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1708.4 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1561.0 KiB
# 24/12/07 00:41:46 WARN DAGScheduler: Broadcasting large task binary with size 1574.3 KiB
# 24/12/07 00:41:47 WARN DAGScheduler: Broadcasting large task binary with size 1692.2 KiB
# 24/12/07 00:41:47 WARN DAGScheduler: Broadcasting large task binary with size 1596.5 KiB
# 24/12/07 00:41:47 WARN DAGScheduler: Broadcasting large task binary with size 1631.2 KiB
# 24/12/07 00:41:47 WARN DAGScheduler: Broadcasting large task binary with size 1615.6 KiB
# Gradient-Boosted Tree model trained successfully!
# Best Gradient-Boosted Tree Model: GBTClassificationModel: uid = GBTClassifier_0999a31debb4, numTrees=20, numClasses=2, numFeatures=100

# %%
# Evaluating the best models on test data
# Logistic Regression
lr_predictions = best_lr_model.transform(test_data)
lr_auc = evaluator.evaluate(lr_predictions)
print(f"Logistic Regression AUC on test data: {lr_auc}")

# Gradient-Boosted Tree
gbt_predictions = best_gbt_model.transform(test_data)
gbt_auc = evaluator.evaluate(gbt_predictions)
print(f"Gradient-Boosted Tree AUC on test data: {gbt_auc}")
# Out:
# Logistic Regression AUC on test data: 0.9043556206948926
# Gradient-Boosted Tree AUC on test data: 0.915854418387934
